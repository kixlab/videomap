# %%
import json
f = open ('./../HowTo100M/caption.json')
data = json.load(f)

# %%
print (len(data))

# %%
count = 0
for key,val in data.items():
    print (key)
    print (val)
    if (count==1): 
        break
    count += 1
# Out:
# nVbIUDjzWY4
# ...

# %%
import json
f = open ('./../raw_caption.json')
data = json.load(f)

# %%
print (len(data))
# Out:
# 1238911

# %%
count = 0
for key,val in data.items():
    scripts = val["text"]
    for script in scripts:
        if "it's okay to use" in script:
            print (key+": "+ script)

    # if (count==10): 
    #     break
    # count += 1
# Out:
# HOGmZ17QJwg: get so cold so it's okay to use your
# eg7fcOT0rws: irritant make sure that it's okay to use
# sDxNRvLgr5s: that it's okay to use a little bit of
# une4Zp75gWU: It's okay to use pressure on the leather,
# and it's okay to use as much pressure as you
# Qga_GEfMRNc: it's okay to use frozen vegetables
# 3KQ7BmYunuc: diaper rash cream it's okay to use with
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/wr/5c10rycs1g1ggrr9wz9yptwr0000gn/T/ipykernel_16148/3043642841.py in <module>
#       3     scripts = val["text"]
#       4     for script in scripts:
# ----> 5         if "it's okay to use" in script:
#       6             print (key+": "+ script)
#       7
#
# TypeError: argument of type 'float' is not iterable

# %%
for key,val in data.items():
    if key=="jet-C42QicY":
        instructions = val["text"]
        for sentence in instructions:
            print (sentence)
        break
# Out:
# hey guys so recently I bleached my hair
# and I am going to take you guys through
# the process and show you what I did I am
# natural I do not have a texturizer I
# don't have a relaxer anything which I
# don't recommend anyone who has a
# texturizer or even a relaxer it doesn't
# matter how long you've had it I don't
# recommend that you do it because I've
# done it before
# and you the hair will literally start
# stretching away and pulling out it's
# just really bad so everything that I use
# will be in the description box but here
# I'm just showing you guys I picked up I
# always pick up a random hair mask
# whatever I feel like will work at the
# time I'll pick it up from Sally's while
# I'm picking up the rest of my products
# so I'm using this shampoo my hair oils
# um for the washing process and I have
# some hair clips I have some Wella
# bleaching powder and I also have my
# mixture like what my bowl to mix in I
# have my 30 volume and I have a 20 volume
# ...
